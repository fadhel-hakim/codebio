# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np
import argparse
import cv2
import os
import time


import keras
from sklearn.model_selection import train_test_split
from keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from keras.applications import VGG16
from keras.layers import AveragePooling2D, Dropout, Flatten, Dense, Input
from keras.models import Model, Sequential
from keras.optimizers import Adam
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from keras.utils import to_categorical
from sklearn.datasets import load_files
from sklearn.preprocessing import LabelBinarizer
from sklearn.metrics import classification_report, confusion_matrix

# %%
data_dir =  r'/gdrive/My Drive/X-Ray_Image_DataSet'

#Load Data
data = load_files(data_dir)

# %%
folders=os.listdir("/gdrive/My Drive/X-Ray_Image_DataSet")
print(folders)
# Out:
# ['PositiveCovid-19', 'NegativeCovid-19']

# %%
#Convert the data and labels to Numpy arrays
X = np.array(data['filenames'])
y = np.array(data['target'])
labels = np.array(data['target_names'])

print('Data files - ',X[0])
print('Target labels - ',y[0])
print('Number of training files : ', X.shape[0])
print('Number of training targets : ', y.shape[0])
# Out:
# Data files -  /gdrive/My Drive/X-Ray_Image_DataSet/NegativeCovid-19/00002678_004.png
# Target labels -  0
# Number of training files :  868
# Number of training targets :  868

# %%
def convert_img_to_arr(file_path_list):
    arr = []
    img_width, img_height = 224,224
    #Loop over the image paths
    for file_path in file_path_list:
        """
           Load the image, swap color channels, and resize it to be a fixed
           224*224 pixels while ignoring aspect ratio
        """
        img = load_img(file_path, target_size = (img_width, img_height))
        img = img_to_array(img)

        #update the data
        arr.append(img)
    return arr

X = np.array(convert_img_to_arr(X))

# The Data Shape
print(X.shape)
print('First training item : ',X[0])
# Out:
# (868, 224, 224, 3)
# First training item :  [[[ 42.  42.  42.]
#   [ 41.  41.  41.]
#   [ 39.  39.  39.]
#   ...
#   [143. 143. 143.]
#   [145. 145. 145.]
#   [155. 155. 155.]]
#
#  [[ 35.  35.  35.]
#   [ 34.  34.  34.]
#   [ 33.  33.  33.]
#   ...
#   [143. 143. 143.]
#   [146. 146. 146.]
#   [155. 155. 155.]]
#
#  [[ 29.  29.  29.]
#   [ 28.  28.  28.]
#   [ 27.  27.  27.]
#   ...
#   [146. 146. 146.]
#   [150. 150. 150.]
#   [161. 161. 161.]]
#
#  ...
#
#  [[ 28.  28.  28.]
#   [ 27.  27.  27.]
#   [ 28.  28.  28.]
#   ...
#   [ 67.  67.  67.]
#   [ 89.  89.  89.]
#   [118. 118. 118.]]
#
#  [[ 28.  28.  28.]
#   [ 28.  28.  28.]
#   [ 28.  28.  28.]
#   ...
#   [ 67.  67.  67.]
#   [ 89.  89.  89.]
#   [118. 118. 118.]]
#
#  [[ 29.  29.  29.]
#   [ 29.  29.  29.]
#   [ 29.  29.  29.]
#   ...
#   [ 68.  68.  68.]
#   [ 91.  91.  91.]
#   [120. 120. 120.]]]

# %%
#First 5 training data.
fig = plt.figure(figsize = (16,9))
for i in range(5):
    ax = fig.add_subplot(1,5,i+1,xticks=[],yticks=[])
    ax.imshow((X[i].astype(np.uint8)))
    plt.title(folders[y[i]])

# %%
# Scale the pixel intenties to the range[0,255]
X = X.astype('float32')/255

# Confirm the number of classes
no_of_classes = len(np.unique(y))
no_of_classes
# Out:
# 2

# %%
y = np.array(to_categorical(y,no_of_classes))
y[0]
# Out:
# array([1., 0.], dtype=float32)

# %%
# Splitting dataset (train to 80%) (valdiation to 10%) (test to 10%)

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
print('The train Data Shape ', X_train.shape[0])

X_test, X_valid, y_test, y_valid = train_test_split(X_test,y_test, test_size = 0.5)
print('The validation Data Shape ', X_valid.shape[0])
print('The test Data Shape ', X_test.shape[0])
# Out:
# The train Data Shape  694
# The validation Data Shape  87
# The test Data Shape  87

# %%
print('The train Data Shape ', X_train.shape[1:])
# Out:
# The train Data Shape  (224, 224, 3)

# %%
# load the VGG16 model without the final layers(include_top=False)
baseModel = VGG16(weights='imagenet', include_top=False, input_shape=X_train.shape[1:])
print("Base Model loaded !")

"""
  Loop over all layers in the base model and freeze them so they will
  not be updated during the first training process
"""
for layer in baseModel.layers:
    layer.trainable = False

baseModel.summary()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 4s 0us/step
# Base Model loaded !
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14714688 (56.13 MB)
# Trainable params: 0 (0.00 Byte)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
headModel = Sequential()
headModel.add(AveragePooling2D(pool_size=(4,4), input_shape=baseModel.output_shape[1:], name="AveragePooling2"))
headModel.add(Flatten( name ="Flatten"))
headModel.add(Dense(64, activation ="relu"))
headModel.add(Dropout(0.5, name="Dropout"))
headModel.add(Dense(no_of_classes, activation="softmax"))

headModel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  AveragePooling2 (AveragePo  (None, 1, 1, 512)         0
#  oling2D)
#
#  Flatten (Flatten)           (None, 512)               0
#
#  dense (Dense)               (None, 64)                32832
#
#  Dropout (Dropout)           (None, 64)                0
#
#  dense_1 (Dense)             (None, 2)                 130
#
# =================================================================
# Total params: 32962 (128.76 KB)
# Trainable params: 32962 (128.76 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
Model = Sequential()
Model.add(baseModel)
Model.add(headModel)

Model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  sequential (Sequential)     (None, 2)                 32962
#
# =================================================================
# Total params: 14747650 (56.26 MB)
# Trainable params: 32962 (128.76 KB)
# Non-trainable params: 14714688 (56.13 MB)
# _________________________________________________________________

# %%
lr = 1e-3
epochs = 50
bs = 8
optimizer = Adam(learning_rate = lr)
Model.compile(optimizer, loss='binary_crossentropy', metrics=['accuracy'])

# %%
# Train the model
epochs = 30

# Initialize the training data augmentation object
train_datagen = ImageDataGenerator(
        rotation_range=15,
        fill_mode ="nearest")

checkpointer = ModelCheckpoint(filepath = "/gdrive/My Drive/Kel2VGG16.h5", save_best_only = True, verbose=1)
start = time.time()

history=Model.fit_generator(train_datagen.flow(X_train, y_train, batch_size = bs),
                            steps_per_epoch = len(X_train)//bs,
                            validation_data = (X_valid, y_valid),
                            validation_steps = len(X_valid)//bs,
                            epochs =epochs,
                            callbacks= [checkpointer])

end = time.time()
duration = end - start
print ('\n This Model took %0.2f seconds (%0.5f minutes) to train for %d epochs'%(duration, duration/60, epochs) )
# Out:
# <ipython-input-17-fc11441c53f4>:12: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history=Model.fit_generator(train_datagen.flow(X_train, y_train, batch_size = bs),
# Epoch 1/30
# 86/86 [==============================] - ETA: 0s - loss: 0.6200 - accuracy: 0.6851
# Epoch 1: val_loss improved from inf to 0.51671, saving model to /gdrive/My Drive/Kel2VGG16.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 86/86 [==============================] - 24s 201ms/step - loss: 0.6200 - accuracy: 0.6851 - val_loss: 0.5167 - val_accuracy: 0.8161
# Epoch 2/30
# 86/86 [==============================] - ETA: 0s - loss: 0.4637 - accuracy: 0.8309
# Epoch 2: val_loss improved from 0.51671 to 0.40943, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 10s 115ms/step - loss: 0.4637 - accuracy: 0.8309 - val_loss: 0.4094 - val_accuracy: 0.8391
# Epoch 3/30
# 86/86 [==============================] - ETA: 0s - loss: 0.3541 - accuracy: 0.8776
# Epoch 3: val_loss improved from 0.40943 to 0.34170, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 10s 118ms/step - loss: 0.3541 - accuracy: 0.8776 - val_loss: 0.3417 - val_accuracy: 0.8506
# Epoch 4/30
# 86/86 [==============================] - ETA: 0s - loss: 0.3056 - accuracy: 0.8892
# Epoch 4: val_loss improved from 0.34170 to 0.31100, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 12s 139ms/step - loss: 0.3056 - accuracy: 0.8892 - val_loss: 0.3110 - val_accuracy: 0.8621
# Epoch 5/30
# 86/86 [==============================] - ETA: 0s - loss: 0.2776 - accuracy: 0.8878
# Epoch 5: val_loss improved from 0.31100 to 0.27826, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 12s 133ms/step - loss: 0.2776 - accuracy: 0.8878 - val_loss: 0.2783 - val_accuracy: 0.8621
# Epoch 6/30
# 86/86 [==============================] - ETA: 0s - loss: 0.2482 - accuracy: 0.9067
# Epoch 6: val_loss improved from 0.27826 to 0.26628, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 11s 126ms/step - loss: 0.2482 - accuracy: 0.9067 - val_loss: 0.2663 - val_accuracy: 0.8506
# Epoch 7/30
# 86/86 [==============================] - ETA: 0s - loss: 0.2511 - accuracy: 0.9038
# Epoch 7: val_loss improved from 0.26628 to 0.25963, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 10s 119ms/step - loss: 0.2511 - accuracy: 0.9038 - val_loss: 0.2596 - val_accuracy: 0.8966
# Epoch 8/30
# 86/86 [==============================] - ETA: 0s - loss: 0.2224 - accuracy: 0.9125
# Epoch 8: val_loss improved from 0.25963 to 0.24207, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 12s 137ms/step - loss: 0.2224 - accuracy: 0.9125 - val_loss: 0.2421 - val_accuracy: 0.8966
# Epoch 9/30
# 86/86 [==============================] - ETA: 0s - loss: 0.2097 - accuracy: 0.9271
# Epoch 9: val_loss improved from 0.24207 to 0.23011, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 13s 154ms/step - loss: 0.2097 - accuracy: 0.9271 - val_loss: 0.2301 - val_accuracy: 0.8851
# Epoch 10/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1958 - accuracy: 0.9213
# Epoch 10: val_loss improved from 0.23011 to 0.22047, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 11s 130ms/step - loss: 0.1958 - accuracy: 0.9213 - val_loss: 0.2205 - val_accuracy: 0.8851
# Epoch 11/30
# 86/86 [==============================] - ETA: 0s - loss: 0.2085 - accuracy: 0.9140
# Epoch 11: val_loss improved from 0.22047 to 0.21361, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 12s 137ms/step - loss: 0.2085 - accuracy: 0.9140 - val_loss: 0.2136 - val_accuracy: 0.8966
# Epoch 12/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1842 - accuracy: 0.9300
# Epoch 12: val_loss did not improve from 0.21361
# 86/86 [==============================] - 10s 119ms/step - loss: 0.1842 - accuracy: 0.9300 - val_loss: 0.2391 - val_accuracy: 0.8966
# Epoch 13/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1924 - accuracy: 0.9111
# Epoch 13: val_loss improved from 0.21361 to 0.20109, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 10s 120ms/step - loss: 0.1924 - accuracy: 0.9111 - val_loss: 0.2011 - val_accuracy: 0.9080
# Epoch 14/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1739 - accuracy: 0.9373
# Epoch 14: val_loss improved from 0.20109 to 0.19332, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 13s 146ms/step - loss: 0.1739 - accuracy: 0.9373 - val_loss: 0.1933 - val_accuracy: 0.9195
# Epoch 15/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1688 - accuracy: 0.9417
# Epoch 15: val_loss improved from 0.19332 to 0.18455, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 13s 150ms/step - loss: 0.1688 - accuracy: 0.9417 - val_loss: 0.1845 - val_accuracy: 0.9195
# Epoch 16/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1625 - accuracy: 0.9417
# Epoch 16: val_loss did not improve from 0.18455
# 86/86 [==============================] - 10s 112ms/step - loss: 0.1625 - accuracy: 0.9417 - val_loss: 0.1874 - val_accuracy: 0.9195
# Epoch 17/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1681 - accuracy: 0.9329
# Epoch 17: val_loss did not improve from 0.18455
# 86/86 [==============================] - 9s 107ms/step - loss: 0.1681 - accuracy: 0.9329 - val_loss: 0.2047 - val_accuracy: 0.9080
# Epoch 18/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1623 - accuracy: 0.9417
# Epoch 18: val_loss improved from 0.18455 to 0.17658, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 13s 150ms/step - loss: 0.1623 - accuracy: 0.9417 - val_loss: 0.1766 - val_accuracy: 0.9310
# Epoch 19/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1525 - accuracy: 0.9388
# Epoch 19: val_loss did not improve from 0.17658
# 86/86 [==============================] - 11s 123ms/step - loss: 0.1525 - accuracy: 0.9388 - val_loss: 0.1835 - val_accuracy: 0.9080
# Epoch 20/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1484 - accuracy: 0.9388
# Epoch 20: val_loss improved from 0.17658 to 0.16985, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 11s 124ms/step - loss: 0.1484 - accuracy: 0.9388 - val_loss: 0.1698 - val_accuracy: 0.9310
# Epoch 21/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1399 - accuracy: 0.9490
# Epoch 21: val_loss did not improve from 0.16985
# 86/86 [==============================] - 10s 111ms/step - loss: 0.1399 - accuracy: 0.9490 - val_loss: 0.1723 - val_accuracy: 0.9310
# Epoch 22/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1429 - accuracy: 0.9504
# Epoch 22: val_loss improved from 0.16985 to 0.16720, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 15s 173ms/step - loss: 0.1429 - accuracy: 0.9504 - val_loss: 0.1672 - val_accuracy: 0.9310
# Epoch 23/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1281 - accuracy: 0.9504
# Epoch 23: val_loss improved from 0.16720 to 0.15431, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 11s 128ms/step - loss: 0.1281 - accuracy: 0.9504 - val_loss: 0.1543 - val_accuracy: 0.9425
# Epoch 24/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1398 - accuracy: 0.9475
# Epoch 24: val_loss improved from 0.15431 to 0.14887, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 11s 125ms/step - loss: 0.1398 - accuracy: 0.9475 - val_loss: 0.1489 - val_accuracy: 0.9425
# Epoch 25/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1448 - accuracy: 0.9417
# Epoch 25: val_loss did not improve from 0.14887
# 86/86 [==============================] - 11s 124ms/step - loss: 0.1448 - accuracy: 0.9417 - val_loss: 0.1699 - val_accuracy: 0.9310
# Epoch 26/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1242 - accuracy: 0.9563
# Epoch 26: val_loss did not improve from 0.14887
# 86/86 [==============================] - 10s 118ms/step - loss: 0.1242 - accuracy: 0.9563 - val_loss: 0.1694 - val_accuracy: 0.9080
# Epoch 27/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1185 - accuracy: 0.9577
# Epoch 27: val_loss did not improve from 0.14887
# 86/86 [==============================] - 9s 102ms/step - loss: 0.1185 - accuracy: 0.9577 - val_loss: 0.1527 - val_accuracy: 0.9655
# Epoch 28/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1283 - accuracy: 0.9534
# Epoch 28: val_loss improved from 0.14887 to 0.14772, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 12s 138ms/step - loss: 0.1283 - accuracy: 0.9534 - val_loss: 0.1477 - val_accuracy: 0.9195
# Epoch 29/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1244 - accuracy: 0.9548
# Epoch 29: val_loss improved from 0.14772 to 0.14652, saving model to /gdrive/My Drive/Kel2VGG16.h5
# 86/86 [==============================] - 12s 135ms/step - loss: 0.1244 - accuracy: 0.9548 - val_loss: 0.1465 - val_accuracy: 0.9195
# Epoch 30/30
# 86/86 [==============================] - ETA: 0s - loss: 0.1321 - accuracy: 0.9504
# Epoch 30: val_loss did not improve from 0.14652
# 86/86 [==============================] - 11s 124ms/step - loss: 0.1321 - accuracy: 0.9504 - val_loss: 0.1491 - val_accuracy: 0.9195
#
#  This Model took 477.40 seconds (7.95662 minutes) to train for 30 epochs

# %%
(eval_loss, eval_accuracy) = Model.evaluate(
     X_test, y_test, batch_size=bs, verbose=2)

print("Accuracy: {:.5f}%".format(eval_accuracy * 100))
print("Loss: {}".format(eval_loss))
# Out:
# 11/11 - 1s - loss: 0.0990 - accuracy: 0.9655 - 611ms/epoch - 56ms/step
# Accuracy: 96.55172%
# Loss: 0.0989561378955841

# %%
# Visualizing the train/validation

import matplotlib.pyplot as plt
def plot(history):
    plt.figure(1)

    # Accuracy
    plt.subplot(211)
    plt.plot(history.history['accuracy'])
    plt.plot(history.history['val_accuracy'])
    plt.title('accuracy vs val_accuracy')
    plt.ylabel('accuracy')
    plt.xlabel('epoch')
    plt.legend(['Train', 'Validation'], loc='lower right')

    # Loss
    plt.subplot(212)
    plt.plot(history.history['loss'])
    plt.plot(history.history['val_loss'])
    plt.title('loss vs val_loss')
    plt.ylabel('loss')
    plt.xlabel('epoch')
    plt.legend(['Train', 'Validation'], loc='upper right')
    plt.tight_layout()
    plt.show()

plot(history)

# %%
# Visualize some random test prediction.
def visualize_pred(y_pred):
# plot a random sample of test images, their predicted labels, and ground truth
    fig = plt.figure(figsize=(16, 9))
    for i, idx in enumerate(np.random.choice(X_test.shape[0], size=16, replace=False)):
        ax = fig.add_subplot(4, 4, i + 1, xticks=[], yticks=[])
        ax.imshow(np.squeeze(X_test[idx]))
        pred_idx = np.argmax(y_pred[idx])
        true_idx = np.argmax(y_test[idx])
        ax.set_title("{} ({})".format(labels[pred_idx], labels[true_idx]),
                     color=("green" if pred_idx == true_idx else "red"))

visualize_pred(Model.predict(X_test))
# Out:
# 3/3 [==============================] - 12s 3s/step

# %%
import seaborn as sns
from sklearn.metrics import confusion_matrix

Y_pred = Model.predict(X_test)
Y_pred_classes = np.argmax(Y_pred,axis = 1)
Y_true = np.argmax(y_test,axis = 1)
confusion_mtx = confusion_matrix(Y_true,Y_pred_classes)
f,ax = plt.subplots(figsize = (8,8))
sns.heatmap(confusion_mtx,annot=True,linewidths = 0.01,cmap="Greens",
            linecolor = "gray",fmt = ".5f",ax=ax
            )
plt.xlabel("predicted label")
plt.ylabel("True Label")
plt.title("confusion matrix")
plt.show()
# Out:
# 3/3 [==============================] - 0s 136ms/step

# %%
print(classification_report(y_test.argmax(axis=1),Y_pred_classes, target_names= labels, digits = 5))
# Out:
#                   precision    recall  f1-score   support
#
# NegativeCovid-19    0.94545   1.00000   0.97196        52
# PositiveCovid-19    1.00000   0.91429   0.95522        35
#
#         accuracy                        0.96552        87
#        macro avg    0.97273   0.95714   0.96359        87
#     weighted avg    0.96740   0.96552   0.96523        87
